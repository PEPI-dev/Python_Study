# %% [markdown]
# # 1. 산술 연산자
# 산술 연산자는 주로 수치 데이터 유형에 대한 기본 산술 연산을 수행하기 위해 사용됩니다.

# %%
print(10 + 3) # + : 더하기
print(10 - 3) # - : 빼기
print(10 * 3) # * : 곱하기
print(10 / 3) # / : 나누기
print(10 // 3) # // : 몫(정수 나누기)
print(10 % 3) # % : 나머지
print(10 ** 3) # ** : 지수(거듭제곱)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# # 2. 비교연산자
# 비교 연산자는 주로 두 값을 비교하는 데 사용되며, 그 결과는 항상 불리언(True 또는 False) 값입니다.

# %%
print(10 > 5) # > : 크다
print(10 < 5) # < : 작다
print(10 >= 5) # >= : 크거나 같다
print(10 <= 5) # <= : 작거나 같다
print(10 == 5) # == : 동등
print(10 != 5) # != : 동등하지 않음
# Out:
# True
# False
# True
# True
# True
# True
# True

# %% [markdown]
# # 3. 할당(대입) 연산자
# 변수에 값을 할당하는데 사용됩니다. 파이썬에서는 기본 할당 연산자 외에도 복합 할당 연산자를 제공하여 코드를 간결하게 작성할 수 있게 도와줍니다.

# %%
num = 10 # = : 할당

num += 1 # += : 더하기 후 할당, (num = num + 1)
print(num)

num -= 1 # -= : 빼기 후 할당
print(num)

num *= 10 # *= : 곱하기 후 할당
print(num)

num /= 10 # /= : 나누기 후 할당, 나누면 float형식으로 바뀜
print(num)

num %= 2 # %= : 나머지 후 할당
print(num)
# //= : 몫 후 할당
# **= : 지수 후 할당
# Out:
# 11
# 10
# 100
# 10.0
# 0.0

# %% [markdown]
# # 4. 비트 연산자
# 비트 연산자는 정수를 이진 비트로 표현했을 때 사용하는 연산자들입니다. 각 연산자는 정수의 비트 단위로 동작합니다.

# %%
# 데이터의 크기를 나타내는 용량단위
# Bit: 가장 기본적인 데이터 단위로, 0 또는 1의 값을 가질 수 있습니다.
# Byte (B): 8 bits와 동일합니다.
# Kilobyte (KB): 1 KB = 1,024 Bytes
# Megabyte (MB): 1 MB = 1,024 KB
# Gigabyte (GB): 1 GB = 1,024 MB
# Terabyte (TB): 1 TB = 1,024 GB

a = 60
b = 13
print (a & b) # & : 비트 단위 AND
print (a | b) # | : 비트 단위 OR
print (a ^ b) # ^ : 비트 단위 XOR
print (~a) # ~ : 비트 단위 NOT # 111100 -> 000011 이렇게 하면 -61이 나오는데 2의 보수 방식 때문이다.
print (a << 2) # << : 왼쪽 시프트, 111100 -> 11110000
print (a >> 2) # >> : 오른쪽 시프트, 111100 -> 1111, 10진법으로 계산하면 15가 나옴
# Out:
# 12
# 61
# 49
# -61
# 240
# 15

# %% [markdown]
# # 5. 논리연산자
# 파이썬에서의 논리 연산자는 주로 불린(Boolean) 값을 조작하기 위해 사용됩니다. 그러나 파이썬의 논리 연산자는 다른 언어와는 다르게, 연산의 결과로 항상 True 또는 False만을 반환하는 것은 아닙니다. 대신 마지막으로 평가된 피연산자의 값을 반환합니다.

# %%
num1 = 10
num2 = 5
result1 = num1 > num2
result2 = num1 == num2
print(result1 and result2)
print(result1 or result2)
print(not result1)
# Out:
# False
# True
# False
# 3
# 5
# 0

# %%
# and: 논리 AND
print(True and 3)
print(3 and 5)
print(3 and 0)
print(0 and 5)
print("-----------")
# or : 논리 OR
print(False or 3)
print(3 or 5)
print(0 or 5)
print("-----------")
# not: 논리 NOT
print(not True) # not은 True의 반대인 False로 출력
print(not 0) # 0이여서 False 인데 not이 붙혀져서 True
print(not 3) # 3은 음의 아닌 숫자여서 True인데 not이 붙혀져서 False
# Out:
# 3
# 5
# 0
# 0
# -----------
# 3
# 3
# 5
# -----------
# False
# True
# False

# %%
bool(10) # True
bool(0) # False
bool("안녕 난 김사과야") # True
bool({}) # False
# Out:
# True

# %% [markdown]
# ※ 파이썬에서 불린(Boolean)으로 평가되는 주요 값
#
# 1. True로 평가되는 주요 값
#
# Boolean: True
# 모든 음이 아닌 숫자: 예를 들어, -1, 1, 3.5 등 (단, 0 제외)
# 문자열과 바이트 문자열: 예를 들어, 'hello', "world", b'hello' (단, 빈 문자열 '' 및 b'' 제외)
# 모든 리스트, 튜플, 세트, 딕셔너리: 예를 들어, [1, 2], {'key': 'value'} 등 (단, 빈 컨테이너 제외)
# 2. False로 평가되는 주요 값
#
# Boolean: False
# 숫자: 0 (정수, 부동 소수점, 복소수 포함)
# 문자열: 빈 문자열 '' 및 빈 바이트 문자열 b''
# 리스트, 튜플, 세트: 빈 리스트 [], 빈 튜플 (), 빈 세트 set()
# 딕셔너리: 빈 딕셔너리 {}
# None: 파이썬의 None 객체도 False로 평가됩니다.
