# %% [markdown]
# # 1. 사용자 정의 함수
# 사용자 정의 함수란 사용자가 특정 작업을 수행하기 위해 직접 작성한 함수를 의미합니다. 파이썬에는 많은 내장 함수들이 있지만, 때로는 우리의 요구사항에 맞게 동작하는 함수를 직접 만들어야 할 때가 있습니다. 이때 사용자 정의 함수를 작성하게 됩니다. 기본적인 구조는 아래와 같습니다.
#
#
#
# ```
# def 함수명(매개변수1, 매개변수2, ...):
#     # 함수 내용
#     return 결과값
# ```

# %% [markdown]
# # 2. 매개변수와 반환 값이 없는 함수

# %%
# defin = 정의한다.
def func1(): # defin뒤에 함수이름을 지정.
  print("처음으로 만드는 함수") # func1라는 함수에 print("처음으로 만드는 함수")를 저장

# %%
func1() # finc1()을 하면 자동으로 내부에 있는 print문을 출력
func1() # 위랑 마찬가지

# %%
# 반복문을 이용해서 0~4까지 총 5번을 돌면서 func1()라는 함수를 실행하라.
for i in range(5) :
  func1()

# %% [markdown]
# # 3. 매개변수가 있고 반환 값이 없는 함수

# %%
def func2(num) :  # ()안에 변수를 선언하는데 해당 변수는 매개변수라고 한다, 매개체이면서 변수이다.(전달되는 변수)
  #num = num # 아래의 코드를 보면 숫자 10을 넣으면 오른쪽의 num이 왼쪽의 num으로 넣는형태로 보면 된다.
  print(f"입력받은 숫자 : {num}")

# %%
func2(10)
# print(num) # 에러발생, 이유 : num은 함수안에서 만들어진것이여서 함수밖에서는 실행이 불가능
func2(5)
func2("안냥") # 타입이 없다.
# 파이썬은 변수에 대한 타입지정이 안되어있어서 아무런 값이나 다 전달이 된다.
# Out:
# 입력받은 숫자 : 10
# 입력받은 숫자 : 5
# 입력받은 숫자 : 안냥

# %%
def func3(start, end) :
    sum = 0
    for i in range(start, end+1) :
        sum += i
    print(f'{start}부터 {end}까지의 합: {sum}')

# %%
func3(1, 10)
func3(1, 100)
func3(10, 20)
# Out:
# 1부터 10까지의 합: 55
# 1부터 100까지의 합: 5050
# 10부터 20까지의 합: 165

# %% [markdown]
# # 4. 반환 값이 있는 함수

# %%
def func4() :
  print("안녕하세요 python")
# Out:
# 안녕하세요 python
# a에 저장된 값 : None

# %%
a = func4() # a에 저장된 값이 없어서 None값 출력
print(f"a에 저장된 값 : {a}") # None값은 특수한 값을 표현하는 방식.즉, 받은 값이 없다라고 생각하면 편하다.
# Out:
# 안녕하세요 python
# a에 저장된 값 : None

# %%
def func5() :
  return '🎁'

# %%
persents = func5() # 리턴을 이용하여 해당 함수가 실행이 되면 값을 func5 = 선물 로 저장을 해라
print(f"presents에 저장된 값 : {persents}") # 그래서 함수를 출력을 하면 리턴된 선물을 뽑아옴.
# Out:
# presents에 저장된 값 : 🎁

# %%
def func6(num1, num2) :
  sum = num1 + num2
  return sum

# %%
result = func6(10, 5)
print(f"입력된 값 : {result}")
# Out:
# 입력된 값 : 15

# %%
# result = func6(10) # 한개만 있으면 num1로 들어간다.
# print(result) # 파라미터랑 매개변수의 값이 정확하게 맞아야한다. 안그러면 에러발생

# %% [markdown]
# # 5. None의 특징
# None은 파이썬에서 특별한 값으로, 아무런 값이 없음을 표현하는 데 사용됩니다. 다른 언어에서의 null 또는 nil과 유사한 개념입니다.
#
# None은 파이썬의 내장 상수이며, 그 자체로 데이터 타입이 NoneType입니다. 모든 None은 동일하므로, 두 개의 None 값을 비교할 때 항상 True를 반환합니다.

# %%
# 1. 기본 초기값 설정 : 변수를 초기화할 때 아무런 값이 할당되지 않았음을 나타내기 위해 None을 사용할 수 있습니다.
x = None
print(x is None)

variable = None # 기본초기값을 설정할때 이렇게 사용할 수 있다.
# Out:
# True

# %%
# 2. 함수의 반환 값으로 사용 : 함수에서 특정 조건에서 아무런 값도 반환하지 않아야 할 때 None을 사용합니다. 사실, 함수에서 return 문이 생략되거나 없으면 기본적으로 None을 반환합니다.
def my_function(x):
    if x > 10:
        return x # x가 10 이하일 때는 아무런 값도 반환하지 않습니다. 실제로는 None이 반환됩니다.

# %%
def my_function(x):
    if x > 10:
        return x
    else :
        return None
# 위에 코드가 더 간결하고 보기 좋음.
# 지금 작성한 코드는 위에 코드의 해석본.

# %%
my_function(15)
# Out:
# 15

# %%
a = my_function(1)
print(a) # None발생.
# Out:
# None

# %%
# 3. 선택적 매개변수의 기본값 : 함수의 매개변수에 기본값으로 None을 할당하여 선택적으로 인자를 전달받을 수 있게 만들 수 있습니다.
def hello(message = None) :
  if message is None :
    print("Hello!")
  else :
    print(message)

# %%
hello("안녕하세요") # 내가 메세지를 전달하면 내가 입력한 메세지를 표출한다.
hello() # 내가 메세지의 내용을 없이 전달 하면 Hello!를 준다.
# Out:
# 안녕하세요
# Hello!

# %%
# 4. 값의 존재 여부 확인 : None을 사용하여 값의 존재 여부를 확인 할 수 있습니다.
def get_data_from_database() :
  pass # 나중에 만들것으로 비워놓는다는 뜻, 값을 비워놓으니 None값이 들어간다.
  # mysql에서 data를 가져옴.

data = get_data_from_database()
print(data)

if data is None :
  print("데이터를 받지 못했습니다.")
else :
  print("데이터를 받았습니다.")
# Out:
# None
# 데이터를 받지 못했습니다.

# %%
# None을 검사할 때는 == 대신 is 연산자를 사용하는 것이 좋습니다. is는 객체의 동일성을 검사하는 반면, ==는 객체의 동등성을 검사하기 때문입니다.
# 객체비교 인지 값의 비교인지 잘 확인 후 사용해야함.
li1 = [1, 2, 3, 4, 5]
li2 = [1, 2, 3, 4, 5]

# 서로 다른 객체(객체 비교)
result1 = li1 is li2 # 두개가 서로 다른 객체(주소값이 다름)이므로 False
# 값이 같은 객체(값 비교)
result2 = li1 == li2 # 동등한 값을 가지고 있어서 True

print(result1)
print(result2)
# Out:
# False
# True

# %% [markdown]
# # 6. 기본값이 설정된 매개변수

# %%
def func6(num1, num2) :
  sum = num1 + num2
  return sum

# %%
print(func6(10, 3))

# %%
# print(func6()) # TypeError: func6() missing 2 required positional arguments: 'num1' and 'num2', 1번과 2번 값이 없다고 에러발생
# print(func6(10)) # TypeError: func6() missing 1 required positional argument: 'num2', 1개만 입력을 해도 2번의 값이 없다고 에러발생

# %%
def func6(num1 = 1, num2 = 2) :
  sum = num1 + num2
  return sum

# %%
print(func6())
# Out:
# 2

# %%
print(func6(10)) # 값이 1개만 있으면 num1에 들어간다.
# Out:
# 12

# %%
print(func6(10, 3))
# Out:
# 13

# %%
print(func6(num2 = 10)) #이렇게 해서 num2만 들어가게 설정
# Out:
# 11

# %% [markdown]
# # 7. 가변 매개변수

# %%
# 함수 내부에서는 매개변수를 튜플로 처리
# print는 가변매개변수로 되어있음. 원하는 값을 아무렇게나 넣어도 된다.
print("안녕", "하세요", "반갑", "습니다!")
# Out:
# 안녕 하세요 반갑 습니다.

# %%
def fune7(*args) :
  result = 0
  # print(args)
  for i in args :
    result += i
  return result

# %%
print(fune7())
# Out:
# 0

# %%
print(fune7(10, 30))
# Out:
# 40

# %%
print(fune7(10, 30, 70, 90, 100))
# Out:
# 300

# %%
# 번외편
# 두개의 차이점 : 이미 출력이 된 상태여서 다시 활용하기 힘들다.
def func_1(num1, num2) :
  sum = num1 + num2
  print(sum)

# %%
# 두개의 차이점 = 변수에 저장을 해서 다시 활용하기 쉽다.
def func_2(num1, num2) :
  sum = num1 + num2
  return sum

# %%
func_1(10, 3)
# Out:
# 13

# %%
func_2(10, 3)
# Out:
# 13

# %% [markdown]
# # 8. 키워드 매개변수

# %%
def func8(id, name, age) :
  print(f"아이디를 입력하세요 : {id}")
  print(f"이름을 입력하세요 : {name}")
  print(f"나이를 입력하세요 : {age}")

# %%
func8("apple", "김사과", "20")
# Out:
# 아이디를 입력하세요 : apple
# 이름을 입력하세요 : 김사과
# 나이를 입력하세요 : 20

# %%
func8(id = "apple", name = "김사과", age = "20")
# Out:
# 아이디를 입력하세요 : apple
# 이름을 입력하세요 : 김사과
# 나이를 입력하세요 : 20

# %%
func8(id = "apple", age = "20", name = "김사과", ) # 이렇게 변수를 지정을 해주면 순서를 바꿔도 이상없이 들어간다.
# Out:
# 아이디를 입력하세요 : apple
# 이름을 입력하세요 : 김사과
# 나이를 입력하세요 : 20

# %%
dic1 = {"id" : "apple", "name" : "김사과", "age" : "20"}
func8(**dic1)
# **은 한번에 데이터를 전송할때 편하게 보낼 수 있다.
# 매개변수가 20개 정도 되는데 일일히 적기 귀찮아서 딕셔너리로 만든다음에 한번에 전송하면 된다.
# Out:
# 아이디를 입력하세요 : apple
# 이름을 입력하세요 : 김사과
# 나이를 입력하세요 : 20

# %%
# 만약 한개만 보낼때
dic1 = {"id" : "apple", "name" : "김사과", "age" : "20"}
func8(*dic1) # 그러면 키값만 전송이 된다.
# Out:
# 아이디를 입력하세요 : id
# 이름을 입력하세요 : name
# 나이를 입력하세요 : age

# %%
def func9(**args) :
  print(args)

# %%
# func9("apple") # 전달 받는 형식이 달라서 에러발생,
#TypeError: func9() takes 0 positional arguments but 1 was given

# %%
func9(id = "apple", name = "김사과", age = 20) # 위쪽 변수에 **args로 설정을 하면 보낼때도 딕셔너리로(풀어서) 해서 보내야 한다.
# Out:
# {'id': 'apple', 'name': '김사과', 'age': 20}

# %%
# 딕셔너리 활용방법
def func9(**args) :
  print(args)
  for i in args :
    if i == "id" :
      id = args[i]
  return id

# %%
user = func9(id = "apple", name = "김사과", age = 20)
print(user)
# Out:
# {'id': 'apple', 'name': '김사과', 'age': 20}
# apple

# %% [markdown]
# # 9. 여러개의 반환 값

# %%
def func10(num1, num2) :
  return num1 + num2, num1 - num2, num1 * num2, num1 / num2

# %%
result1, result2, result3, result4 = func10(10, 3)
print(f"덧셈 : {result1}, 뺄셈 : {result2}, 곱셈 : {result3}, 나눗셈 : {result4}")
# Out:
# 덧셈 : 13, 뺄셈 : 7, 곱셈 : 30, 나눗셈 : 3.3333333333333335

# %%
# 메모리낭비를 안하면서, 원하는 값만 가져오고 싶을때는
_, _, result3, _ = func10(10,3)
print(result3)
# Out:
# 30

# %% [markdown]
# # 10. 파이썬 함수와 메모리
# 1. 메모리 로드
#
# * 함수 정의: 파이썬에서 함수는 객체로 취급됩니다. 따라서 함수를 정의하면 해당 함수는 메모리 상에 적재되며, 함수 이름은 이 함수 객체를 참조하게 됩니다.
#
# * 변수 할당: 함수를 다른 변수에 할당하면 그 변수는 원래의 함수 객체를 참조합니다. 이는 파이썬의 함수가 일급 객체(first-class object)로 취급되기 때문에 가능합니다.

# %%
def my_function():
    print("Hello, World!")

func_var = my_function
func_var()  # 이렇게 호출해도 "Hello, World!" 가 출력됩니다.

# %% [markdown]
# 2. 메모리 제거
#
# * 참조 카운트: 파이썬의 메모리 관리는 주로 참조 카운팅(reference counting)에 기반합니다. 객체를 참조하는 변수나 요소의 수를 세어서 이 카운트가 0이 되면 해당 객체는 메모리에서 제거될 수 있게 됩니다.
#
# * Garbage Collection: 참조 카운트가 0인 객체들은 바로 메모리에서 제거되지 않습니다. 대신, 파이썬의 가비지 컬렉터(garbage collector)가 이런 객체들을 주기적으로 찾아서 메모리에서 제거합니다.
#
# * 함수의 경우: 함수도 파이썬 객체이므로 참조 카운팅과 가비지 컬렉션의 원칙에 따라 동작합니다. 함수를 참조하는 변수나 요소가 없게 되면 해당 함수는 가비지 컬렉터에 의해 메모리에서 제거될 수 있습니다.
#
# * 명시적 제거: del 명령어를 사용하여 함수에 대한 참조를 명시적으로 제거할 수 있습니다. 하지만 이것이 함수가 즉시 메모리에서 제거된다는 것을 보장하지는 않습니다.
#
# * 종료 시: 파이썬 프로그램이 종료될 때, 모든 메모리는 OS에 반환됩니다. 따라서 프로그램이 종료되면 함수와 관련된 모든 메모리도 함께 반환됩니다.

# %%
def my_function():
    print("Hello, World!")

del my_function
# 이후 my_function()을 호출하려고 하면 오류가 발생합니다.
