# %% [markdown]
# # 1. 딕셔너리
# 파이썬의 딕셔너리는 키-값 쌍을 저장하는 변경 가능한(mutable) 컬렉션입니다.

# %%
# 1. 생성
#딕셔너리는 중괄호 {}를 사용하여 생성하고, 키-값 쌍들은 쉼표 ,로 구분됩니다. 각 키-값 쌍은 콜론 :으로 구분됩니다.
dic1 = {}
print(dic1)
print(type(dic1)) # type = dict
# Out:
# {}
# <class 'dict'>

# %%
dic2 = {1 : '김사과', 2 : '반하나', 3 : '오렌지', 4 : '이메론'}
print(dic2)
print(dic2[1]) # key를 넣으면 지정한 숫자의 데이터를 출력
print(dic2[2])
# Out:
# {1: '김사과', 2: '반하나', 3: '오렌지', 4: '이메론'}
# 김사과
# 반하나

# %%
dic3 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(dic3)
print(dic3['no'])
print(dic3['userid'])
# key하고 velue에는 원하는 값이 들어갈 수 있다.
# key로 튜플은 들어갈 수 있다.(특수한 경우)
# key는 변경가능한 list는 불가능
# Out:
# {'no': 1, 'userid': 'apple', 'name': '김사과', 'hp': '010-1111-1111'}
# 1
# apple

# %%
# 2. 변경가능 : 딕셔너리는 변경 가능합니다. 따라서, 딕셔너리에 키-값 쌍을 추가하거나 제거하거나, 기존의 키의 값을 변경할 수 있습니다.
dic1 = {1 : 'apple'}
print(dic1)

dic1[100] = 'orange'
print(dic1)

dic1[50] = 'melon'
print(dic1)
# key값 + 원하는데이터를 입력을 하면 추가가된다.

# del로 삭제하는방법
del dic1[1]
print(dic1)

print(type(dic1))
# Out:
# {1: 'apple'}
# {1: 'apple', 100: 'orange'}
# {1: 'apple', 100: 'orange', 50: 'melon'}
# {100: 'orange', 50: 'melon'}
# <class 'dict'>

# %%
# 3. 키, 값의 제약
# 딕셔너리의 키는 변경 불가능한(immutable) 타입이어야 합니다. 예를 들어, 문자열, 정수, 튜플은 딕셔너리의 키로 사용할 수 있지만, 리스트는 딕셔너리의 키로 사용할 수 없습니다. 하지만 딕셔너리의 값은 어떤 타입이든 상관없습니다.

dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
dic1['no'] = 10 # key의 값은 변경이 안되고 해당 데이터가 변경이 된다. 그래서 키를 바꾸고 싶으면 삭제후 재등록을 하면 된다.
print(dic1)

dic1['점수'] = [90, 100, 50] # list의 값도 잘 들어감.
print(dic1)
#key는 변경 불가능한 녀석만 들어갈 수 있다.
dic1[(1, 2, 3)] = ('🍕', '🍔', '🍟')# 소괄호여서 tuple
print(dic1)

# dic1[[1,2,3]] = ['🍕', '🍔', '🍟'] # 에러발생 []는 리스트여서 딕셔너리 에러발생
# print(dic1)

dic1['과일'] = {'사과' : '🍎', '딸기' : '🍓', '앵두' : '🍒'}
print(dic1)
# Out:
# {'no': 10, 'userid': 'apple', 'name': '김사과', 'hp': '010-1111-1111'}
# {'no': 10, 'userid': 'apple', 'name': '김사과', 'hp': '010-1111-1111', '점수': [90, 100, 50]}
# {'no': 10, 'userid': 'apple', 'name': '김사과', 'hp': '010-1111-1111', '점수': [90, 100, 50], (1, 2, 3): ('🍕', '🍔', '🍟')}
# {'no': 10, 'userid': 'apple', 'name': '김사과', 'hp': '010-1111-1111', '점수': [90, 100, 50], (1, 2, 3): ('🍕', '🍔', '🍟'), '과일': {'사과': '🍎', '딸기': '🍓', '앵두': '🍒'}}

# %%
# 4. 함수와 메서드
# 딕셔너리는 여러 함수와 메소드를 가지고 있습니다.

# len() : 딕셔너리의 길이(키-값 쌍의 개수)를 구할 수 있는 함수
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(len(dic1))
# Out:
# 4

# %%
# keys(): 딕셔너리의 모든 키를 반환하는 메서드
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(dic1.keys())
# Out:
# dict_keys(['no', 'userid', 'name', 'hp'])

# %%
# values(): 딕셔너리의 모든 값을 반환하는 메서드
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(dic1.values())
# Out:
# dict_values([1, 'apple', '김사과', '010-1111-1111'])

# %%
# items(): 딕셔너리의 모든 키-값 쌍을 반환하는 메서드
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(dic1.items())
# Out:
# dict_items([('no', 1), ('userid', 'apple'), ('name', '김사과'), ('hp', '010-1111-1111')])

# %%
# get(): 특정 키의 값을 반환. 만약 그 키가 딕셔너리에 없으면, None을 반환하는 메서드
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(dic1['userid'])
# print(dic1['age']) # 없는 값이 있으면 error발생

print(dic1.get('userid'))
print(dic1.get('age')) # 데이터가없으면 'None'값 출력
print(dic1.get('age', '나이를 알 수 없음')) # 'age가 없을때만 나이를 알 수 없음을 출력'
# Out:
# apple
# apple
# None
# 나이를 알 수 없음

# %%
# pop(): 특정 키의 값을 제거하고 반환. 만약 그 키가 딕셔너리에 없으면, KeyError가 발생하는 메서드
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print(dic1.pop('hp')) # in-place
print(dic1)
# print(dic1.pop('age')) # 없으면 error 발생
# Out:
# 010-1111-1111
# {'no': 1, 'userid': 'apple', 'name': '김사과'}

# %%
# 5. 멤버십 테스트
# in 연산자를 사용하여 딕셔너리에 특정 키가 있는지 확인할 수 있습니다.
dic1 = {'no' : 1, 'userid' : 'apple', 'name' : '김사과', 'hp' : '010-1111-1111'}
print('hp' in dic1) # 맞으면 True
print('age' in dic1) # 틀리면 False
# Out:
# True
# False
